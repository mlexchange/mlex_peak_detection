# %%
from numpy import genfromtxt
my_data = genfromtxt('TiNiSn_500C_Y20190218_14x14_t60_0001_bkgdSub_1D.csv', delimiter=',')

# %%
# !ls
# Out:
# params
# params_noise10
# params_split
# TiNiSn_500C_Y20190218_14x14_t60_0001_bkgdSub_1D.csv
# TiNiSn_500C_Y20190218_14x14_t60_0002_bkgdSub_1D.csv
# TiNiSn_500C_Y20190218_14x14_t60_0003_bkgdSub_1D.csv
# TiNiSn_500C_Y20190218_14x14_t60_0004_bkgdSub_1D.csv
# TiNiSn_500C_Y20190218_14x14_t60_0005_bkgdSub_1D.csv
# TiNiSn_500C_Y20190218_14x14_t60_0006_bkgdSub_1D.csv
# TiNiSn_500C_Y20190218_14x14_t60_0007_bkgdSub_1D.csv
# TiNiSn_500C_Y20190218_14x14_t60_0008_bkgdSub_1D.csv
# TiNiSn_500C_Y20190218_14x14_t60_0009_bkgdSub_1D.csv
# TiNiSn_500C_Y20190218_14x14_t60_0010_bkgdSub_1D.csv
# TiNiSn_500C_Y20190218_14x14_t60_0011_bkgdSub_1D.csv
# TiNiSn_500C_Y20190218_14x14_t60_0012_bkgdSub_1D.csv
# TiNiSn_500C_Y20190218_14x14_t60_0013_bkgdSub_1D.csv
# TiNiSn_500C_Y20190218_14x14_t60_0014_bkgdSub_1D.csv
# TiNiSn_500C_Y20190218_14x14_t60_0015_bkgdSub_1D.csv
# TiNiSn_500C_Y20190218_14x14_t60_0016_bkgdSub_1D.csv
# TiNiSn_500C_Y20190218_14x14_t60_0017_bkgdSub_1D.csv
# ...

# %%
import matplotlib.pyplot as plt

# %%
# !pip install matplotlib
# Out:
# ...
#      |████████████████████████████████| 10.3 MB 381 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.2 MB 10.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.0 MB 10.9 MB/s eta 0:00:01
# ...

# %%
plt.plot(my_data)

# %%
x=my_data[:,0]
y=my_data[:,1]

# %%
plt.plot(x,y)

# %%
x
# Out:
# array([1.50250007, 1.50750007, 1.51250007, 1.51750007, 1.52250008,
#        1.52750008, 1.53250008, 1.53750008, 1.54250008, 1.54750008,
#        1.55250008, 1.55750008, 1.56250008, 1.56750008, 1.57250008,
#        1.57750008, 1.58250008, 1.58750008, 1.59250009, 1.59750009,
#        1.60250009, 1.60750009, 1.61250009, 1.61750009, 1.62250009,
#        1.62750009, 1.63250009, 1.63750009, 1.64250009, 1.64750009,
#        1.65250009, 1.65750009, 1.6625001 , 1.6675001 , 1.6725001 ,
#        1.6775001 , 1.6825001 , 1.6875001 , 1.6925001 , 1.6975001 ,
#        1.7025001 , 1.7075001 , 1.7125001 , 1.7175001 , 1.7225001 ,
#        1.7275001 , 1.73250011, 1.73750011, 1.74250011, 1.74750011,
#        1.75250011, 1.75750011, 1.76250011, 1.76750011, 1.77250011,
#        1.77750011, 1.78250011, 1.78750011, 1.79250011, 1.79750011,
#        1.80250012, 1.80750012, 1.81250012, 1.81750012, 1.82250012,
#        1.82750012, 1.83250012, 1.83750012, 1.84250012, 1.84750012,
# ...
